# %%
marks=[20,21,76,69]
print("avg=",sum(marks)/4)
# Out:
# avg= 46.5

# %%
name="nomi"
print("hi this is", name)
# Out:
# hi this is nomi

# %%
names = ["  ali khan ", "SARA AHMED", "bilal  ", " Ayesha Khan"]

for raw in names:
    clean = raw.strip().title()
    print(clean)
# Out:
# Ali Khan
# Sara Ahmed
# Bilal
# Ayesha Khan

# %%
new_user="nouman"

# %%
if new_user in names:
    print("its already there")
else:
    names.append("nouman")

print(names)
# Out:
# its already there
# ['  ali khan ', 'SARA AHMED', 'bilal  ', ' Ayesha Khan', 'nouman']

# %%
names[0]
# Out:
# '  ali khan '

# %%
def main():
    print("Hello from hello-python!")


if __name__ == "__main__":
    main()
# Out:
# Hello from hello-python!
